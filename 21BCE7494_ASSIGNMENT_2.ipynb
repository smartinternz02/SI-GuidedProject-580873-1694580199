# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = sns.load_dataset("car_crashes")

# %%
dataset
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
dataset.head(3)
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ

# %%
sns.__version__
# Out:
# '0.12.2'

# %%
dataset.tail()
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 46   12.7     2.413    3.429          11.049       11.176       768.95
# 47   10.6     4.452    3.498           8.692        9.116       890.03
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 50   17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses abbrev
# 46      153.72     VA
# 47      111.62     WA
# 48      152.56     WV
# 49      106.62     WI
# 50      122.04     WY

# %%
dataset.shape
# Out:
# (51, 8)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
dataset.describe()
# Out:
#            total   speeding    alcohol  not_distracted  no_previous  \
# count  51.000000  51.000000  51.000000       51.000000    51.000000
# mean   15.790196   4.998196   4.886784       13.573176    14.004882
# std     4.122002   2.017747   1.729133        4.508977     3.764672
# min     5.900000   1.792000   1.593000        1.760000     5.900000
# 25%    12.750000   3.766500   3.894000       10.478000    11.348000
# 50%    15.600000   4.608000   4.554000       13.857000    13.775000
# 75%    18.500000   6.439000   5.604000       16.140000    16.755000
# max    23.900000   9.450000  10.038000       23.661000    21.280000
#
#        ins_premium  ins_losses
# count    51.000000   51.000000
# mean    886.957647  134.493137
# std     178.296285   24.835922
# min     641.960000   82.750000
# 25%     768.430000  114.645000
# 50%     858.970000  136.050000
# 75%    1007.945000  151.870000
# max    1301.520000  194.780000

# %%
sns.scatterplot(x="total",y="speeding",data=dataset)
# Out:
# <Axes: xlabel='total', ylabel='speeding'>

# %% [markdown]
# Inference:from the plot we can say that as bill amount increases tip is alos incre

# %%
sns.scatterplot(x="alcohol",y="speeding",data=dataset)
# Out:
# <Axes: xlabel='alcohol', ylabel='speeding'>

# %% [markdown]
# Inference:from the plot we can say that as bill amount increases tip is alos increasing

# %%
sns.scatterplot(x="alcohol",y="not_distracted",data=dataset)
# Out:
# <Axes: xlabel='alcohol', ylabel='not_distracted'>

# %%
sns.lineplot(x="alcohol",y="no_previous",data=dataset,ci=None)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7932\1228083119.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="alcohol",y="no_previous",data=dataset,ci=None)
# <Axes: xlabel='alcohol', ylabel='no_previous'>

# %%
sns.lineplot(x="alcohol",y="ins_premium",data=dataset,ci=None)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7932\4054170764.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="alcohol",y="ins_premium",data=dataset,ci=None)
# <Axes: xlabel='alcohol', ylabel='ins_premium'>

# %%
sns.distplot(dataset["alcohol"])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7932\1566322857.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["alcohol"])
# <Axes: xlabel='alcohol', ylabel='Density'>

# %%
sns.distplot(dataset["not_distracted"])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7932\1509731173.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["not_distracted"])
# <Axes: xlabel='not_distracted', ylabel='Density'>

# %%
sns.relplot(x="total",y="alcohol",data=dataset,hue="ins_premium")

# %%
dataset["ins_premium"].value_counts()
# Out:
# 784.55     1
# 905.99     1
# 1029.87    1
# 746.54     1
# 1301.52    1
# 869.85     1
# 1234.31    1
# 708.24     1
# 688.75     1
# 697.73     1
# 881.51     1
# 804.71     1
# 1148.99    1
# 816.21     1
# 858.97     1
# 669.31     1
# 767.91     1
# 1004.75    1
# 809.38     1
# 716.20     1
# 768.95     1
# 890.03     1
# 992.61     1
# 670.31     1
# 732.28     1
# 790.32     1
# 1053.48    1
# 641.96     1
# 899.47     1
# 827.34     1
# 878.41     1
# 835.50     1
# 1068.73    1
# 1137.87    1
# 1273.89    1
# 1160.13    1
# 913.15     1
# 861.18     1
# 803.11     1
# 896.07     1
# 710.46     1
# 649.06     1
# 780.45     1
# 872.51     1
# 1281.55    1
# 661.88     1
# 1048.78    1
# 1011.14    1
# 1110.61    1
# 777.18     1
# 791.14     1
# Name: ins_premium, dtype: int64

# %%
sns.barplot(data=dataset,x="total",y="ins_premium",ci=None)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7932\3970687983.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=dataset,x="total",y="ins_premium",ci=None)
# <Axes: xlabel='total', ylabel='ins_premium'>

# %%
sns.barplot(data=dataset,x="total",y="alcohol",hue="not_distracted")
# Out:
# <Axes: xlabel='total', ylabel='alcohol'>

# %%
sns.countplot(x="alcohol",data=dataset)
# Out:
# <Axes: xlabel='alcohol', ylabel='count'>

# %%
sns.jointplot(x="total",y="alcohol",data=dataset)

# %%
sns.boxplot(x="total",y="ins_premium",data=dataset)
# Out:
# <Axes: xlabel='total', ylabel='ins_premium'>

# %%
corr=dataset.corr()
corr
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7932\1091080309.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=dataset.corr()
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# ...

# %%
sns.heatmap(corr,annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.subplots(figsize=(20,15))
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
dataset.alcohol.value_counts()
# Out:
# 5.208     2
# 5.640     1
# 4.218     1
# 4.704     1
# 3.480     1
# 3.136     1
# 4.968     1
# 3.567     1
# 10.038    1
# 4.794     1
# 5.771     1
# 3.328     1
# 5.642     1
# 9.799     1
# 9.416     1
# 6.402     1
# 5.655     1
# 7.372     1
# 1.808     1
# 4.080     1
# 3.429     1
# 3.498     1
# 6.664     1
# 4.554     1
# 5.215     1
# 5.474     1
# 4.525     1
# 5.456     1
# 5.824     1
# 3.360     1
# 3.808     1
# 3.888     1
# 4.860     1
# 1.593     1
# 5.191     1
# 3.900     1
# 7.175     1
# 4.437     1
# 4.352     1
# 4.205     1
# 3.925     1
# 4.272     1
# 4.922     1
# 6.765     1
# 4.530     1
# 4.000     1
# 2.870     1
# 3.948     1
# 2.784     1
# 5.568     1
# Name: alcohol, dtype: int64

# %%
dataset.isnull().any()
# Out:
# total             False
# speeding          False
# alcohol           False
# not_distracted    False
# no_previous       False
# ins_premium       False
# ins_losses        False
# abbrev            False
# dtype: bool

# %%
dataset.isnull().sum()
# Out:
# total             0
# speeding          0
# alcohol           0
# not_distracted    0
# no_previous       0
# ins_premium       0
# ins_losses        0
# abbrev            0
# dtype: int64

# %%
dataset.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %% [markdown]
# ### 4.Seperate dependent  and independent variables
